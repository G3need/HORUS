# %% [markdown]
# # 👁️ HORUS KEY: Sovereign Digital Travel & FinTech Ecosystem
# ### Google Colab One-Click Live Launcher
# Runs the complete Sovereign Monolith dashboard on Google Colab with a temporary public Gradio URL.

# %%
# 1. Safely Reset Working Directory and Clone Fresh Repository
import os, shutil
os.chdir("/content")
if os.path.exists("/content/HORUS"):
    shutil.rmtree("/content/HORUS")
# !git clone https://github.com/G3need/HORUS.git /content/HORUS
# %cd /content/HORUS

# 2. Install System and Python Dependencies
# !apt-get update -qq && apt-get install -y -qq libzbar0
# !pip install -q gradio qrcode reportlab google-genai opencv-python pyzbar

# 3. Launch HORUS Monolith
# !python horus.py
